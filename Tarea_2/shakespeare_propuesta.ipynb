# %% [markdown]
# # Introducción a la Ciencia de Datos: Tarea 1
#
# Este notebook contiene el código de base para realizar la Tarea 1 del curso. Puede copiarlo en su propio repositorio y trabajar sobre el mismo.
# Las **instrucciones para ejecutar el notebook** están en la [página inicial del repositorio](https://github.com/DonBraulio/introCD).
#
# Se utiliza el lenguaje Python y la librería Pandas. Si no tiene ninguna familiaridad con la librería, se recomienda realizar algún tutorial introductorio (ver debajo).
# También se espera que los alumnos sean proactivos a la hora de consultar las documentaciones de las librerías y del lenguaje, para entender el código provisto.
# Además de los recursos provistos en la [página del curso](https://eva.fing.edu.uy/course/view.php?id=1378&section=1), los siguientes recursos le pueden resultar interesantes:
#  - [Pandas getting started](https://pandas.pydata.org/docs/getting_started/index.html#getting-started) y [10 minutes to pandas](https://pandas.pydata.org/docs/user_guide/10min.html): Son parte de la documentación en la página oficial de Pandas.
#  - [Kaggle Learn](https://www.kaggle.com/learn): Incluye tutoriales de Python y Pandas.
#
#
# Si desea utilizar el lenguaje R y está dispuesto a no utilizar (o traducir) este código de base, también puede hacerlo.
#
# En cualquier caso, **se espera que no sea necesario revisar el código para corregir la tarea**, ya que todos los resultados y análisis relevantes deberían estar en el **informe en formato PDF**.

# %% [markdown]
# ## Cargar bibliotecas (dependencias)
# Recuerde instalar los requerimientos (`requirements.txt`) en el mismo entorno donde está ejecutando este notebook (ver [README](https://github.com/DonBraulio/introCD)).

# %%
from time import time
from pathlib import Path

import pandas as pd
import matplotlib.pyplot as plt
from sqlalchemy import create_engine
import seaborn as sns
import re

# %% [markdown]
# # PARTE 1: Cargado y limpieza de datos

# %% [markdown]
# ## 1.a.1. Carga de datos

# %%
# Creamos el directorio Tarea_1/data/shakespeare
data_dir = Path("data") / "shakespeare"
data_dir.mkdir(parents=True, exist_ok=True)


def load_table(table_name, engine):
    """
    Leer la tabla con SQL y guardarla como CSV,
    o cargarla desde el CSV si ya existe
    """
    path_table = data_dir / f"{table_name}.csv"
    if not path_table.exists():
        print(f"Consultando tabla con SQL: {table_name}")
        t0 = time()
        df_table = pd.read_sql(f"SELECT * FROM {table_name}", engine)
        t1 = time()
        print(f"Tiempo: {t1 - t0:.1f} segundos")

        print(f"Guardando: {path_table}\n")
        df_table.to_csv(path_table)
    else:
        print(f"Cargando tabla desde CSV: {path_table}")
        df_table = pd.read_csv(path_table, index_col=[0])
    return df_table


print("Conectando a la base...")
conn_str = "mysql+pymysql://guest:relational@relational.fit.cvut.cz:3306/Shakespeare"
engine = create_engine(conn_str)

# DataFrame con todas las obras:
df_works = load_table("works", engine)

# Todos los párrafos de todas las obras
df_paragraphs = load_table("paragraphs", engine)

# Todos los capitulos de las obras
df_chapters = load_table("chapters", engine)

# Todos los personajes de las obras
df_characters = load_table("characters", engine)

print("Tablas cargadas!")
# Out:
# Conectando a la base...
# Cargando tabla desde CSV: data\shakespeare\works.csv
# Cargando tabla desde CSV: data\shakespeare\paragraphs.csv
# Cargando tabla desde CSV: data\shakespeare\chapters.csv
# Cargando tabla desde CSV: data\shakespeare\characters.csv
# Tablas cargadas!

# %% [markdown]
# ## 1.a.2. Analizar calidad de los datos

# %% [markdown]
# ### 1.a.2.1. Analizar datos faltantes

# %%
# convertir los string vacios en na
df_works = df_works.mask(df_works == '')
df_chapters = df_chapters.mask(df_chapters == '')
df_paragraphs = df_paragraphs.mask(df_paragraphs == '')
df_characters = df_characters.mask(df_characters == '')

# chequear si los df tienen na o nulos
df_works_nulos= df_works.isna().values.any() or df_works.isnull().values.any()
df_chapters_nulos= df_chapters.isna().values.any() or df_chapters.isnull().values.any()
df_paragraphs_nulos= df_paragraphs.isna().values.any() or df_paragraphs.isnull().values.any()
df_characters_nulos = df_characters.isna().values.any() or df_characters.isnull().values.any()

print("df_works tiene nulos = " + str(df_works_nulos))
print("df_chapters tiene nulos = " + str(df_chapters_nulos))
print("df_paragraphs tiene nulos = " + str(df_paragraphs_nulos))
print("df_characters tiene nulos = " + str(df_characters_nulos))
# Out:
# df_works tiene nulos = False
# df_chapters tiene nulos = False
# df_paragraphs tiene nulos = False
# df_characters tiene nulos = True

# %%
df_characters[df_characters["Abbrev"].isna()] # algunos personajes no tienen abreviatura

count_charactes_abbrev_na = df_characters['Abbrev'].isna().sum()
count_charactes_abbrev = len(df_characters['Abbrev'].index)

#Calculo la proporcion de nulos
characters_abbrev_prop = (count_charactes_abbrev_na * 100)/count_charactes_abbrev 
print ('Prop: ' + str(characters_abbrev_prop))
# Out:
# Prop: 0.3949447077409163

# %%
df_characters.head(10)
# la columna description tiene nulos
# Out:
#    id           CharName             Abbrev Description
# 0   1   First Apparition   First Apparition         NaN
# 1   2      First Citizen      First Citizen         NaN
# 2   3  First Conspirator  First Conspirator         NaN
# 3   4    First Gentleman    First Gentleman         NaN
# 4   5         First Goth         First Goth         NaN
# 5   6     First Murderer     First Murderer         NaN
# 6   7     First Musician     First Musician         NaN
# 7   8     First Musician     First Musician         NaN
# 8   9      First Officer      First Officer         NaN
# 9  10       First Player              1Play         NaN

# %% [markdown]
# ### 1.a.2.2. Analizar characters.Description problema de calidad de datos

# %%
#Cuento la cantidad de nulos en la columna Descripcion
count_charactes_desc_na = df_characters['Description'].isna().sum()
print ('NaNs: ' + str(count_charactes_desc_na))
#Cuento la cantidad de filas totales de la tabla characters
count_charactes_desc = len(df_characters['Description'].index)
print ('Tot: ' + str(count_charactes_desc))
#Calculo la proporcion de nulos
characters_desc_prop = (count_charactes_desc_na * 100)/count_charactes_desc 
print ('Prop: ' + str(characters_desc_prop))

#Quitamos la columna Description por estar mayoritariamente vacia
df_characters.drop(columns=["Description"], inplace=True)
print ('Se quita la columna characters_desc_prop por tener mas de un 50% de nulos')
# Out:
# NaNs: 646
# Tot: 1266
# Prop: 51.026856240126385
# Se quita la columna characters_desc_prop por tener mas de un 50% de nulos

# %% [markdown]
# ### 1.a.2.3. Analizar cantidad de párrafos por personaje

# %%
#Agrego a la informacion de los parrafos la informacion del personaje
df_paragraphs_characters = pd.merge(df_paragraphs, df_characters[["id", "CharName"]], left_on="character_id", right_on="id",)
#Agrego la informacion del capitulo para poder obtener la informacion de la obra
df_paragraphs_characters = pd.merge(df_paragraphs_characters, df_chapters[["id", "work_id"]], left_on="chapter_id", right_on="id", suffixes=('_xx','_yy'))
#Obtengo la informaicon de la obra
df_paragraphs_characters = pd.merge(df_paragraphs_characters, df_works[["id", "Title"]], left_on="work_id", right_on="id", suffixes=('_xxx','_yyy'))
df_paragraphs_characters
# Out:
#          id_x  ParagraphNum
# 0      630863             3  \
# 1      630871            48
# 2      630864             4
# 3      630866            20
# 4      630868            22
# ...       ...           ...
# 35460  665511          1190
# 35461  665512          1196
# 35462  665513          1202
# 35463  665514          1208
# 35464  665515          1214
#
#                                                PlainText  character_id
# 0      [Enter DUKE ORSINO, CURIO, and other Lords; Mu...          1261  \
# 1                                               [Exeunt]          1261
# 2      If music be the food of love, play on;\nGive m...           840
# 3                                           What, Curio?           840
# 4      Why, so I do, the noblest that I have:\nO, whe...           840
# ...                                                  ...           ...
# 35460  By this, the boy that by her side lay kill'd\n...           894
# ...

# %% [markdown]
# Se elimina del dataframe los parrafos del Poet, por ser una representacion del yo lirico y no un personaje. Por un motivo similar se elimina las indicaciones de direccion.

# %%
df_paragraphs_characters=df_paragraphs_characters[df_paragraphs_characters['CharName'] != 'Poet']
df_paragraphs_characters=df_paragraphs_characters[df_paragraphs_characters['CharName'] != '(stage directions)']
df_paragraphs_characters=df_paragraphs_characters[df_paragraphs_characters['CharName'] != 'All']
df_paragraphs_characters
# Out:
#          id_x  ParagraphNum
# 2      630864             4  \
# 3      630866            20
# 4      630868            22
# 5      630870            39
# 6      630865            19
# ...       ...           ...
# 34727  666318          3438
# 34728  666323          3460
# 34729  666325          3475
# 34730  666297          3367
# 34731  666313          3419
#
#                                                PlainText  character_id
# 2      If music be the food of love, play on;\nGive m...           840  \
# 3                                           What, Curio?           840
# 4      Why, so I do, the noblest that I have:\nO, whe...           840
# 5      O, she that hath a heart of that fine frame\nT...           840
# 6                             Will you go hunt, my lord?           297
# ...                                                  ...           ...
# 34727  Music, awake her; strike!\n[Music]\n'Tis time;...           866
# ...

# %%
# Los personajes puedne repetirse en las obras?
df_paragraphs_characters.groupby(["CharName"])["Title"].nunique().sort_values(ascending=False) # resp: hay repetidos
# Out:
# CharName
# Messenger           23
# Servant             21
# Lord                 9
# First Lord           8
# Second Gentleman     8
#                     ..
# Frederick            1
# French Herald        1
# French Soldier       1
# Frenchman            1
# Young Siward         1
# Name: Title, Length: 922, dtype: int64

# %% [markdown]
# #### 1.a.2.3.a El personaje puede repetirse en mas de una obra

# %%
paragraphs_per_character = df_paragraphs_characters.groupby(["CharName"])["CharName"].count().sort_values(ascending=False)
paragraphs_per_character
char_show = paragraphs_per_character[:10][::-1]
p = plt.barh(char_show.index, char_show.values, label=char_show.values)
plt.bar_label(p, label_type='center')

_ = plt.xticks(rotation=90)

plt.title("Top 10 de personajes con más párrafos en todos las obras", fontweight="bold")
plt.xlabel("cantidad de párrafos")
plt.ylabel("personajes")
# Out:
# Text(0, 0.5, 'personajes')

# %% [markdown]
# #### 1.a.2.3.a El personaje es local a la obra

# %%
#Creo una nueva columna con los datos del personaje y de la obra 
df_paragraphs_characters ["Character (Work)"] = df_paragraphs_characters["CharName"].astype(str)+ ' (' + df_paragraphs_characters["Title"].astype(str) +")"
#Cuento la cantidad de parrafor por la nueva columna
paragraphs_per_character_work = df_paragraphs_characters.groupby(["Character (Work)"])["Character (Work)"].count().sort_values(ascending=False)
paragraphs_per_character_work
# Out:
# Character (Work)
# Hamlet (Hamlet)                      358
# Othello (Othello)                    274
# Iago (Othello)                       272
# Timon (Timon of Athens)              210
# Cleopatra (Antony and Cleopatra)     204
#                                     ...
# Joseph (Taming of the Shrew)           1
# First Citizen (Henry VI, Part II)      1
# Sixth Citizen (Coriolanus)             1
# Chorus (Troilus and Cressida)          1
# First Soldier (Henry VI, Part I)       1
# Name: Character (Work), Length: 1263, dtype: int64

# %%
char_show = paragraphs_per_character_work[:10][::-1]
p = plt.barh(char_show.index, char_show.values, label=char_show.values)
plt.bar_label(p, label_type='center')

_ = plt.xticks(rotation=90)

plt.title("Top 10 de personajes con más párrafos por cada obra", fontweight="bold")
plt.xlabel("cantidad de párrafos")
plt.ylabel("personajes")
# Out:
# Text(0, 0.5, 'personajes')

# %% [markdown]
# ## 1.b. Graficar la obra a lo largo del tiempo

# %% [markdown]
# Veamos primero la cantidad de obras por año.

# %%
works_per_year = df_works.groupby(["Date"])["Date"].count()
a = plt.plot(works_per_year.index, works_per_year.values)
_ = plt.xticks(rotation=90)

plt.title("Cantidad de obras a lo largo del tiempo", fontweight="bold")
plt.xlabel("Fecha")
plt.ylabel("Cantidad de obras")
# Out:
# Text(0, 0.5, 'Cantidad de obras')

# %% [markdown]
# Separemos ahora por genero
# Lo estaba haciendo como lineas pero creo que una grafica de barras apiladas puede rendir mas

# %%
works_genre_per_year = df_works.groupby(["Date", "GenreType"], as_index=False).count()
works_genre_per_year = works_genre_per_year.drop(columns=["id","LongTitle"]).rename(columns={'Title':'Quantity'})

df_works_genre_per_year = works_genre_per_year.pivot(index='Date', columns='GenreType', values='Quantity')

df_works_genre_per_year.plot.bar(stacked=True)

plt.title("Cantidad de obras a lo largo del tiempo según su género", fontweight="bold")
plt.xlabel("Fecha")
plt.ylabel("Cantidad de obras")
# Out:
# Text(0, 0.5, 'Cantidad de obras')

# %% [markdown]
# ## 1.c. Normalizar el texto

# %%
def clean_text(df, column_name):
    # Convertir todo a minúsculas
    result = df[column_name].str.lower()

    # se quitan las indicaciones de escena
    result = result.loc[~result.str.startswith("[") & ~result.str.endswith("]")]

    # Quitar signos de puntuación y cambiarlos por espacios (" ")
    # TODO: completar signos de puntuación faltantes
    for punc in ["\n", ",", ";", ".", "?", "!", ":", "-","--", "\"", "(", ")","&c","[","]",]:
        result = result.str.replace(punc, " ")
    
    # Cambiar las contracciones por sus palabras ---> TAMBIEN PARA LAS NEGATIVAS?
    contractions = [{"contraction": "'re", "word": "are"}, {"contraction": "'ll", "word": "will"}, 
                    {"contraction": "'ve", "word": "have"}, {"contraction": "'twas", "word": "it was"}]    
    for c in contractions:
        result = result.str.replace(c["contraction"], c["word"])
        
    # Para las contracciones que no detectamos eliminamos el apostrofe y el palabra abreviada.
    
    result = result.str.replace(r"'[^']*?\s", " ", regex=True)
    
    

    #cambiar digitos por sus palabras
    digits =[{'digit':'0','word':'zero'},{'digit':'1','word':'one'},{'digit':'2','word':'two'},{'digit':'3','word':'three'},
             {'digit':'4','word':'four'},{'digit':'5','word':'five'},{'digit':'6','word':'six'},{'digit':'7','word':'seven'},
             {'digit':'8','word':'eight'},{'digit':'9','word':'nine'}]

    for d in digits:
        result = result.str.replace(d["digit"], d["word"])

    return result


# Creamos una nueva columna CleanText a partir de PlainText
df_paragraphs["CleanText"] = clean_text(df_paragraphs, "PlainText")

# eliminamos las frases limpiadas que quedaron vacias (indicaciones de escena)
df_paragraphs.dropna(subset=["CleanText"], inplace=True)

# Veamos la diferencia
df_paragraphs[["PlainText", "CleanText"]]

df_paragraphs
# Out:
#            id  ParagraphNum
# 1      630864             4  \
# 2      630865            19
# 3      630866            20
# 4      630867            21
# 5      630868            22
# ...       ...           ...
# 35459  666322          3458
# 35460  666323          3460
# 35461  666324          3467
# 35462  666325          3475
# 35463  666326          3483
#
#                                                PlainText  character_id
# 1      If music be the food of love, play on;\nGive m...           840  \
# 2                             Will you go hunt, my lord?           297
# 3                                           What, Curio?           840
# 4                                              The hart.           297
# 5      Why, so I do, the noblest that I have:\nO, whe...           840
# ...                                                  ...           ...
# 35459  Ay, and make't manifest where she has lived,\n...           898
# ...

# %%
# Convierte párrafos en listas "palabra1 palabra2 palabra3" -> ["palabra1", "palabra2", "palabra3"]
df_paragraphs["WordList"] = df_paragraphs["CleanText"].str.split()

# Veamos la nueva columna creada
# Notar que a la derecha tenemos una lista: [palabra1, palabra2, palabra3]
df_paragraphs[["CleanText", "WordList"]]
# Out:
#                                                CleanText
# 1      if music be the food of love  play on  give me...  \
# 2                             will you go hunt  my lord
# 3                                           what  curio
# 4                                              the hart
# 5      why  so i do  the noblest that i have  o  when...
# ...                                                  ...
# 35459  ay  and make manifest where she has lived  or ...
# 35460  that she is living  were it but told you  shou...
# 35461  you gods  look down and from your sacred vials...
# 35462  there time enough for that  lest they desire u...
# 35463  o  peace  paulina  thou shouldst a husband tak...
#
#                                                 WordList
# 1      [if, music, be, the, food, of, love, play, on,...
# 2                        [will, you, go, hunt, my, lord]
# 3                                          [what, curio]
# ...

# %%
# Nuevo dataframe: cada fila ya no es un párrafo, sino una sóla palabra
df_words = df_paragraphs.explode("WordList")

# eliminar las plabras ya limpiadas que son nulas (indicaciones de escena)
df_words.dropna(subset=["CleanText"], inplace=True)

# Quitamos estas columnas redundantes
df_words.drop(columns=["CleanText", "PlainText"], inplace=True)

# Renombramos la columna WordList -> word
df_words.rename(columns={"WordList": "word"}, inplace=True)

# Verificar que el número de filas es mucho mayor
df_words
# Out:
#            id  ParagraphNum  character_id  chapter_id      word
# 1      630864             4           840       18704        if
# 1      630864             4           840       18704     music
# 1      630864             4           840       18704        be
# 1      630864             4           840       18704       the
# 1      630864             4           840       18704      food
# ...       ...           ...           ...         ...       ...
# 35463  666326          3483           667       19648      were
# 35463  666326          3483           667       19648  dissever
# 35463  666326          3483           667       19648   hastily
# 35463  666326          3483           667       19648      lead
# 35463  666326          3483           667       19648      away
#
# [838141 rows x 5 columns]

# %% [markdown]
# # PARTE 2: Conteo de palabras y visualizaciones

# %% [markdown]
# ##2.a Visualizacion de palabras mas frecuentes

# %% [markdown]
# Realizamos un conteo de palabras y observamos que las mas pronunciadas son las palabras vacias (stopwords en ingles), como  artículos, pronombres, preposiciones que deberiamos filtrar del analisis.

# %%
words_count = df_words.groupby(["word"])["word"].count().sort_values(ascending=False)
words_count[0:10:].plot.bar()

plt.title("Top 10 de palabras más utilizadas", fontweight="bold")
plt.xlabel("palabras")
plt.ylabel("ocurrencias")
# Out:
# Text(0, 0.5, 'ocurrencias')

# %%
#Definimos una lista de stopwords a filtrar, obtenidad de NTLK
stop_words_english = ["i","me","my","myself","we","our","ours","ourselves","you","your","yours","yourself","yourselves","he","him","his","himself","she","her","hers","herself","it","its","itself","they","them","their","theirs","themselves","what","which","who","whom","this","that","these","those","am","is","are","was","were","be","been","being","have","has","had","having","do","does","did","doing","a","an","the","and","but","if","or","because","as","until","while","of","at","by","for","with","about","against","between","into","through","during","before","after","above","below","to","from","up","down","in","out","on","off","over","under","again","further","then","once","here","there","when","where","why","how","all","any","both","each","few","more","most","other","some","such","no","nor","not","only","own","same","so","than","too","very","s","t","can","will","just","don","should","now"]
words_count_filtered = words_count[~words_count.index.isin(stop_words_english)]
words_count_filtered
# Out:
# word
# thou            5701
# thy             4081
# shall           3588
# thee            3262
# o               3000
#                 ...
# pellmell           1
# peloponnesus       1
# pelter             1
# contemns           1
# zwagger            1
# Name: word, Length: 23267, dtype: int64

# %%
#Definimos una segunda lista para las stopwords del ingles antiguo, obtenida de CLTK
stop_words_old_english = ["a","abutan","abuten","abuton","ac","æ","æfter","after","ær","at","æt","æthindan","amang","and","anforngean","ar","be","begeonde","beheonan","beheonon","behindan","behwon","beneoðan","beo","beoð","beon","beonne","beoþ","betweoh","betweohs","betweonan","betweonum","betweox","betweoxn","betwih","betwisc","betwux","bewestan","bi","bið","binnan","binnan","bist","biþ","butan","butan","buton","ða","ðæm","ðær","ðære","ðæs","ðæt","ðam","ðar","ðara","ðare","ðas","ðe","ðeah","ðenden","ðeos","ðes","ðider","ðin","ðinre","ðis","ðisra","ðisre","ðisse","ðisses","ðissra","ðissum","ðon","ðu","ðurh","ðurhut","ðy","ðys","eac","eala","eart","eft","eom","eow","eower","for","foranto","forðam","forðon","forþam","forþon","fram","from","from","ge","gea","geo","gif","git","he","heo","heom","heora","hi","hie","hiera","him","hiom","hiora","hira","hire","his","hit","hwa","hwæm","hwæs","hwæt","hwam","hwile","hwon","hwonne","hwy","ic","in","inc","incer","innan","inne","into","is","iu","lice","me","mec","mid","mid","midd","min","minne","næron","ne","nu","oð","oð","oðat","oððæt","oððat","of","ofer","oft","on","ond","onforan","oninnan","onmiddan","onufan","onuppan","oþ","oþat","oþþæt","oþþat","sam","sceal","sculon","se","seo","siððan","siðþan","sie","sien","sindon","siþðan","siþþan","sum","sume","swa","swelc","swilc","swylc","sy","sylfa","sylfe","sylfes","sylfum","to","to","toeacan","toforan","toforen","toforon","towiðere","towiðre","towiþere","towiþre","unc","uncer","under","unga","ure","us","wære","wæron","wæs","was","we","wearð","wearþ","weorðen","weorþen","weorþ","weorð","weorþen","weorðen","were","weren","wes","wesað","wesaþ","wesan","wesaþ","wesende","wið","wiþ","wiðer","wiðforan","wiðgeondan","wiðutan","wiþer","wiþforan","wiþgeondan","wiþutan","wile","willað","willaþ","wille","willen","wit","wolde","wolden","woldon","ymbe","ymbe","ymbutan","ys","þa","þæm","þær","þære","þæs","þæt","þam","þar","þara","þare","þas","þe","þeah","þenden","þeos","þes","þider","þin","þinre","þis","þisra","þisre","þisse","þisses","þissra","þissum","þon","þu","þurh","þy","þys"]
words_count_filtered_by_old = words_count_filtered[~words_count_filtered.index.isin(stop_words_english)]
words_count_filtered_by_old[0:10:].plot.bar()
plt.title("Top 10 de palabras más utilizadas (sin stop words)", fontweight="bold")
plt.xlabel("palabras")
plt.ylabel("ocurrencias")
# Out:
# Text(0, 0.5, 'ocurrencias')

# %% [markdown]
# La segunda lista de stop words no encontro ninguna elemento a eliminar.
# Graficamos entonces dos nubes de palabras, la primera con las stopwords y la segunda sin ellas.

# %%
# %pip install wordcloud
from wordcloud import WordCloud

# Create and generate a word cloud image:
wordcloud = WordCloud().generate_from_frequencies(words_count)

# Display the generated image:
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 22.0.4; however, version 23.1.2 is available.
# You should consider upgrading via the 'c:\introcd\introcd_grupo_17\venv\Scripts\python.exe -m pip install --upgrade pip' command.

# %%
# Create and generate a word cloud image:
wordcloud = WordCloud().generate_from_frequencies(words_count_filtered_by_old)

# Display the generated image:
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# ## Personajes con mayor cantidad de palabras

# %%
#Agrego a la informacion de los parrafos la informacion del personaje
df_paragraphs_characters = pd.merge(df_words, df_characters[["id", "CharName"]], left_on="character_id", right_on="id",)
#Agrego la informacion del capitulo para poder obtener la informacion de la obra
df_paragraphs_characters = pd.merge(df_paragraphs_characters, df_chapters[["id", "work_id"]], left_on="chapter_id", right_on="id", suffixes=('_xx','_yy'))
#Obtengo la informaicon de la obra
df_paragraphs_characters = pd.merge(df_paragraphs_characters, df_works[["id", "Title"]], left_on="work_id", right_on="id", suffixes=('_xxx','_yyy'))

# %% [markdown]
# Se elimina del dataframe los parrafos del Poet, por ser una representacion del yo lirico y no un personaje. Por un motivo similar se elimina las indicaciones de direccion.

# %%
df_paragraphs_characters=df_paragraphs_characters[df_paragraphs_characters['CharName'] != 'Poet']
df_paragraphs_characters=df_paragraphs_characters[df_paragraphs_characters['CharName'] != '(stage directions)']
df_paragraphs_characters
# Out:
#           id_x  ParagraphNum  character_id  chapter_id       word  id_y
# 0       630864             4           840       18704         if   840  \
# 1       630864             4           840       18704      music   840
# 2       630864             4           840       18704         be   840
# 3       630864             4           840       18704        the   840
# 4       630864             4           840       18704       food   840
# ...        ...           ...           ...         ...        ...   ...
# 838136  665876          1651          1197       19642     wishes  1197
# 838137  665876          1651          1197       19642  earnestly  1197
# 838138  665876          1651          1197       19642        you  1197
# 838139  665876          1651          1197       19642      never  1197
# 838140  665876          1651          1197       19642        may  1197
#
#        CharName  id_xxx  work_id  id_yyy              Title
# ...

# %%
#Creo una nueva columna con los datos del personaje y de la obra 
df_paragraphs_characters ["Character (Work)"] = df_paragraphs_characters["CharName"].astype(str)+ ' (' + df_paragraphs_characters["Title"].astype(str) +")"
#Cuento la cantidad de parrafor por la nueva columna
paragraphs_per_character_work = df_paragraphs_characters.groupby(["Character (Work)"])["Character (Work)"].count().sort_values(ascending=False)
paragraphs_per_character_work
# Out:
# Character (Work)
# Hamlet (Hamlet)                    11730
# Henry V (Henry V)                   8385
# Iago (Othello)                      8035
# Vincentio (Measure for Measure)     6372
# Coriolanus (Coriolanus)             6211
#                                    ...
# Thieves (Henry IV, Part I)             1
# Second Senator (Cymbeline)             1
# Third Soldier (Julius Caesar)          1
# All (Taming of the Shrew)              1
# All (Richard II)                       1
# Name: Character (Work), Length: 1270, dtype: int64

# %%
char_show = paragraphs_per_character_work[:10][::-1]
p = plt.barh(char_show.index, char_show.values, label=char_show.values)
plt.bar_label(p, label_type='center')

_ = plt.xticks(rotation=90)


plt.title("Top 10 de personajes con mayor cantidad de palabras intra obra", fontweight="bold")
plt.xlabel("cantidad de palabras")
plt.ylabel("personajes")
# Out:
# Text(0, 0.5, 'personajes')

# %%
grouped_df = df_paragraphs_characters.groupby(['CharName', 'Title']).size().reset_index(name='Incidencias')
grouped_df[grouped_df["Title"] == "Henry IV, Part I"].sort_values(by="Incidencias", ascending=False)
# Out:
#                     CharName             Title  Incidencias
# 359                 Falstaff  Henry IV, Part I         5362
# 553                  Henry V  Henry IV, Part I         4442
# 580    Hotspur (Henry Percy)  Henry IV, Part I         4339
# 550                 Henry IV  Henry IV, Part I         2526
# 336        Earl of Worcester  Henry IV, Part I         1428
# 521                Glendower  Henry IV, Part I          610
# 342             Edward Poins  Henry IV, Part I          559
# 1242                  Vernon  Henry IV, Part I          461
# 790                 Mortimer  Henry IV, Part I          451
# 637               Lady Percy  Henry IV, Part I          420
# 576          Hostess Quickly  Henry IV, Part I          414
# 498                 Gadshill  Henry IV, Part I          347
# 312          Earl of Douglas  Henry IV, Part I          343
# 122                    Blunt  Henry IV, Part I          299
# 332     Earl of Westmoreland  Henry IV, Part I          297
# ...

# %%
paragraphs_per_character = df_paragraphs_characters.groupby(["CharName"])["CharName"].count().sort_values(ascending=False)
paragraphs_per_character
char_show = paragraphs_per_character[:10][::-1]
p = plt.barh(char_show.index, char_show.values, label=char_show.values)
plt.bar_label(p, label_type='center')

_ = plt.xticks(rotation=90)


plt.title("Top 10 de personajes con mayor cantidad de palabras inter obra", fontweight="bold")
plt.xlabel("cantidad de palabras")
plt.ylabel("personajes")
# Out:
# Text(0, 0.5, 'personajes')

# %% [markdown]
# Análisis del personaje con mayor apariciones inter obra: Henry V

# %%
# agrupacion por personaje y obra, para obtener las indicdencias de cada palabra
grouped_df = df_paragraphs_characters.groupby(['CharName', 'Title']).size().reset_index(name='Incidencias')

# se genera el ranking de las incidencias para cada obra
grouped_df['Ranking'] = grouped_df.groupby('Title')['Incidencias'].rank(ascending=False)

# se obtiene la posicion de Henry V en cada una de las obras que aparece
obras_HenryV = grouped_df[grouped_df["CharName"] == "Henry V"]['Title']
grouped_df[(grouped_df["Title"].isin(obras_HenryV)) & (grouped_df["CharName"] == "Henry V")]
# Out:
#     CharName              Title  Incidencias  Ranking
# 553  Henry V   Henry IV, Part I         4442      2.0
# 554  Henry V  Henry IV, Part II         2213      3.0
# 555  Henry V            Henry V         8385      1.0
